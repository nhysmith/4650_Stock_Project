# %% [markdown]
# <a href="https://colab.research.google.com/github/nhysmith/4650_Stock_Project/blob/main/CS_4650_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 12.6 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %% [markdown]
# **Week 1**
# ---
# For my week 1 data analysis I tried to learn more about the stock
# market and I traded very conservatively. I only bought a total of 20 shares. I based my tradeds off real world data analysis, meaning that I did some research about the stock market and combined it with my knowledge of current events and I used that information to make my 3 initial trades.

# %%
msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
msft.major_holders

# show institutional holders
msft.institutional_holders

# show balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
opt = msft.option_chain('2021-11-19')
# data available via: opt.calls, opt.puts

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft = yf.Ticker("MSFT")

# get stock info
msft.info
# Out:
# {'52WeekChange': 0.6220828,
#  'SandP52WeekChange': 0.3224138,
#  'address1': 'One Microsoft Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 344.17,
#  'askSize': 1000,
#  'averageDailyVolume10Day': 21004250,
#  'averageVolume': 23643217,
#  'averageVolume10days': 21004250,
#  'beta': 0.862337,
#  'beta3Year': None,
#  'bid': 344.14,
#  'bidSize': 800,
#  'bookValue': 20.242,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Redmond',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 343.53,
#  'currentRatio': 2.165,
#  'dateShortInterest': 1635465600,
#  'dayHigh': 345.1,
#  'dayLow': 342.25,
#  'debtToEquity': 51.938,
#  'dividendRate': 2.48,
#  'dividendYield': 0.0073,
#  'earningsGrowth': 0.489,
#  'earningsQuarterlyGrowth': 0.476,
#  'ebitda': 85745000448,
#  'ebitdaMargins': 0.48648998,
#  'enterpriseToEbitda': 29.28,
#  'enterpriseToRevenue': 14.244,
# ...

# %%
# get historical market data
hist = msft.history(period="max")
print(hist)
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 1986-03-13    0.055898    0.064119  ...       0.00           0.0
# 1986-03-14    0.061378    0.064667  ...       0.00           0.0
# 1986-03-17    0.063570    0.065215  ...       0.00           0.0
# 1986-03-18    0.064667    0.065215  ...       0.00           0.0
# 1986-03-19    0.063022    0.063570  ...       0.00           0.0
# ...                ...         ...  ...        ...           ...
# 2021-11-15  336.923616  337.262991  ...       0.00           0.0
# 2021-11-16  335.066992  340.047900  ...       0.00           0.0
# 2021-11-17  338.940002  342.190002  ...       0.62           0.0
# 2021-11-18  338.179993  342.450012  ...       0.00           0.0
# 2021-11-19  342.640015  345.100006  ...       0.00           0.0
#
# [8998 rows x 7 columns]

# %%
data = yf.download("NVDA TSLA ULTA", start="2021-01-01", end="2021-11-18")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
print(data)
# Out:
#              Adj Close                           ...    Volume
#                   NVDA         TSLA        ULTA  ...      NVDA      TSLA     ULTA
# Date                                             ...
# 2021-01-04  131.036606   729.770020  282.470001  ...  56064000  48638200  1010000
# 2021-01-05  133.946915   735.109985  280.359985  ...  32276000  32245200   754400
# 2021-01-06  126.050354   755.979980  291.190002  ...  58042400  44700000   770700
# 2021-01-07  133.339874   816.039978  292.420013  ...  46148000  51498900   686200
# 2021-01-08  132.667877   880.020020  294.260010  ...  29252800  75055500   692500
# ...                ...          ...         ...  ...       ...       ...      ...
# 2021-11-11  303.899994  1063.510010  395.570007  ...  33217200  22396600   383200
# 2021-11-12  303.899994  1033.420044  396.500000  ...  41215100  25182300   391200
# 2021-11-15  300.250000  1013.390015  401.730011  ...  38490900  34775600   346400
# ...

# %%
pip install altair vega_datasets

# %%
nvda= yf.download('NVDA', period='1y')
tsla= yf.download('TSLA', period='1y')
ulta= yf.download('ULTA', period='1y')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# **NVDA**
# ---
#
# I based this trade off research I did using mainly Reddit. I found a post that analyzed NVDIA's stock. I was initially interested in going with a chip manufactor, because I have personally seen how high the demand has been recently and the chip shortage and crypto-boom have helped to ensure this shortage will continue for the forseeable future. This post was the main reason I picked this stock. I bought 10 shares, half of the total amount I purchased this week. In addition to using the post, and other peripheral knowledge, I looked at the how the closing price changed over the past 1 day, 5 days, month, 1 year and 5 years. The price generally went up as time went on and that was the final piece of data that helped me conclude that this was one of the trades I wanted to make.
#
# [NVDA Reddit reference](https://www.reddit.com/r/stocks/comments/qx1l1a/i_analyzed_nvda_so_you_dont_have_to/)

# %%
price1 = alt.Chart(nvda.reset_index()).mark_line().encode(
    x='Date:T',
    y='Close',
    tooltip=['Date','Open','Close','High','Low','Volume']
).properties(
    width=600,
    height=200
)

price1
# Out:
# alt.Chart(...)

# %% [markdown]
# **TSLA**
# ---
# For this trade I wanted to buy Tesla stock because of the recent news about Elon Musk basically being required to sell some of his stock. Most of the time recently when I hear about the stock market, I hear about how Elon Musk is affecting it or at least appearing to do so. So for this purchase I decided to only buy 5 shares, because my analysis was mainly based off of name recognition and a limited undestanding of Elon Musk related financial news. I also looked at the how the closing price changed over the past 1 day, 5 days, month, 1 year and 5 years. The price generally went up as time went on and that was the main factor in deciding to purchase this stock.

# %%
price2 = alt.Chart(tsla.reset_index()).mark_line().encode(
    x='Date:T',
    y='Close',
    tooltip=['Date','Open','Close','High','Low','Volume']
).properties(
    width=600,
    height=200
)

price2
# Out:
# alt.Chart(...)

# %% [markdown]
# **ULTA**
# ---
#
# This trade was an attempt at buying a stock related to something I'm a little more familiar with. Ulta has had a decent year. They recently joined a partnership with Target and they have been adding a lot of sought after brands into their stores. Another reason I believed this stock would be a good choice is because of the upcoming holiday season. I figured that increased sales this time of year might correlate to an increase of the stock price. For this purchase I decided to only buy 5 shares, because my analysis was mainly based off of name recognition and some previous knowledge of the company. I also looked at the how the closing price changed over the past 1 day, 5 days, month, 1 year and 5 years. The price generally went up as time went on and that was the one of the factors in deciding to purchase this stock.
#
# [Ulta Target reference](https://corporate.target.com/article/2021/07/ulta-beauty-at-target-launch)

# %%
price3 = alt.Chart(ulta.reset_index()).mark_line().encode(
    x='Date:T',
    y='Close',
    tooltip=['Date','Open','Close','High','Low','Volume']
).properties(
    width=600,
    height=200
)

price3
# Out:
# alt.Chart(...)
